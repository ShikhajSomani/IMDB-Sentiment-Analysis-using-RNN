# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
sent = [
    "the glass of milk",
    "the glass of juice",
    "the cup of tea",
    "I am a good boy",
    "I am a good developer",
    "Understand the meaning of words",
    "Your videos are good"
]

# %%
# Define the vocabulary size
voc_size = 10000

# %%
# OneHot Representation
onehot_rep = [one_hot(words, voc_size) for words in sent]
onehot_rep
# Out:
# [[9758, 1884, 8035, 3719],
#  [9758, 1884, 8035, 7351],
#  [9758, 8707, 8035, 8740],
#  [7902, 2612, 5231, 6725, 9482],
#  [7902, 2612, 5231, 6725, 2178],
#  [7997, 9758, 32, 8035, 6272],
#  [482, 3742, 3096, 6725]]

# %%
# Word Embedding Representation
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_length = 8
embedded_docs = pad_sequences(onehot_rep, padding='pre',maxlen=sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0    0 9758 1884 8035 3719]
#  [   0    0    0    0 9758 1884 8035 7351]
#  [   0    0    0    0 9758 8707 8035 8740]
#  [   0    0    0 7902 2612 5231 6725 9482]
#  [   0    0    0 7902 2612 5231 6725 2178]
#  [   0    0    0 7997 9758   32 8035 6272]
#  [   0    0    0    0  482 3742 3096 6725]]

# %%
# Feature Representation
dim = 10

# %%
model = Sequential()
model.add(Embedding(10000, dim, input_length=sent_length, input_shape=(sent_length,)))
model.compile('adam','mse')
# Out:
# c:\anaconda3\envs\imdb_env\Lib\site-packages\keras\src\layers\core\embedding.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_4 (Embedding)         │ (None, 8, 10)          │       100,000 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 100,000 (390.62 KB)
#  Trainable params: 100,000 (390.62 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# array([[[ 0.04413015,  0.048686  ,  0.006501  , -0.02744819,
#          -0.04518657,  0.02030418, -0.04457892,  0.03195561,
#          -0.04405531,  0.00417024],
#         [ 0.04413015,  0.048686  ,  0.006501  , -0.02744819,
#          -0.04518657,  0.02030418, -0.04457892,  0.03195561,
#          -0.04405531,  0.00417024],
#         [ 0.04413015,  0.048686  ,  0.006501  , -0.02744819,
#          -0.04518657,  0.02030418, -0.04457892,  0.03195561,
#          -0.04405531,  0.00417024],
#         [ 0.04413015,  0.048686  ,  0.006501  , -0.02744819,
#          -0.04518657,  0.02030418, -0.04457892,  0.03195561,
#          -0.04405531,  0.00417024],
#         [ 0.04929603,  0.02197849, -0.01432655, -0.02270597,
#          -0.03673823, -0.02676839,  0.02234468,  0.02094333,
#           0.00256709,  0.03930967],
#         [ 0.01717177, -0.04809495,  0.00635279,  0.03877095,
#          -0.02381608,  0.00574363,  0.04001215,  0.03407898,
#          -0.03609248, -0.0054876 ],
#         [-0.01425738,  0.01909899, -0.0068404 ,  0.04898309,
#           0.03358111, -0.03556133,  0.01801005,  0.00573983,
#           0.02217904,  0.045626  ],
#         [ 0.01075939, -0.02508246,  0.03044936, -0.00063821,
#          -0.01721774,  0.03959969,  0.00388902, -0.02030658,
#           0.03264349, -0.03134723]],
#
#        [[ 0.04413015,  0.048686  ,  0.006501  , -0.02744819,
#          -0.04518657,  0.02030418, -0.04457892,  0.03195561,
#          -0.04405531,  0.00417024],
#         [ 0.04413015,  0.048686  ,  0.006501  , -0.02744819,
#          -0.04518657,  0.02030418, -0.04457892,  0.03195561,
#          -0.04405531,  0.00417024],
#         [ 0.04413015,  0.048686  ,  0.006501  , -0.02744819,
#          -0.04518657,  0.02030418, -0.04457892,  0.03195561,
#          -0.04405531,  0.00417024],
#         [ 0.04413015,  0.048686  ,  0.006501  , -0.02744819,
#          -0.04518657,  0.02030418, -0.04457892,  0.03195561,
#          -0.04405531,  0.00417024],
#         [ 0.04929603,  0.02197849, -0.01432655, -0.02270597,
#          -0.03673823, -0.02676839,  0.02234468,  0.02094333,
#           0.00256709,  0.03930967],
#         [ 0.01717177, -0.04809495,  0.00635279,  0.03877095,
#          -0.02381608,  0.00574363,  0.04001215,  0.03407898,
#          -0.03609248, -0.0054876 ],
#         [-0.01425738,  0.01909899, -0.0068404 ,  0.04898309,
#           0.03358111, -0.03556133,  0.01801005,  0.00573983,
#           0.02217904,  0.045626  ],
#         [-0.0188476 , -0.02267711, -0.04739232, -0.04232366,
#          -0.0006086 , -0.01822893, -0.01667479, -0.00199945,
#          -0.04972681,  0.04269398]],
#
#        [[ 0.04413015,  0.048686  ,  0.006501  , -0.02744819,
#          -0.04518657,  0.02030418, -0.04457892,  0.03195561,
#          -0.04405531,  0.00417024],
#         [ 0.04413015,  0.048686  ,  0.006501  , -0.02744819,
#          -0.04518657,  0.02030418, -0.04457892,  0.03195561,
#          -0.04405531,  0.00417024],
#         [ 0.04413015,  0.048686  ,  0.006501  , -0.02744819,
#          -0.04518657,  0.02030418, -0.04457892,  0.03195561,
#          -0.04405531,  0.00417024],
#         [ 0.04413015,  0.048686  ,  0.006501  , -0.02744819,
#          -0.04518657,  0.02030418, -0.04457892,  0.03195561,
#          -0.04405531,  0.00417024],
#         [ 0.04929603,  0.02197849, -0.01432655, -0.02270597,
#          -0.03673823, -0.02676839,  0.02234468,  0.02094333,
#           0.00256709,  0.03930967],
#         [-0.03919494,  0.01240091,  0.04769547,  0.00878187,
#          -0.03849368,  0.00926949, -0.00756487,  0.02655124,
#           0.01351514, -0.0424721 ],
#         [-0.01425738,  0.01909899, -0.0068404 ,  0.04898309,
#           0.03358111, -0.03556133,  0.01801005,  0.00573983,
#           0.02217904,  0.045626  ],
#         [-0.02331225,  0.03513317, -0.00526845,  0.03851766,
#          -0.01231645,  0.01958254,  0.00583044,  0.00178393,
#          -0.03558289,  0.01156173]],
#
#        [[ 0.04413015,  0.048686  ,  0.006501  , -0.02744819,
#          -0.04518657,  0.02030418, -0.04457892,  0.03195561,
#          -0.04405531,  0.00417024],
#         [ 0.04413015,  0.048686  ,  0.006501  , -0.02744819,
#          -0.04518657,  0.02030418, -0.04457892,  0.03195561,
#          -0.04405531,  0.00417024],
#         [ 0.04413015,  0.048686  ,  0.006501  , -0.02744819,
#          -0.04518657,  0.02030418, -0.04457892,  0.03195561,
#          -0.04405531,  0.00417024],
#         [ 0.01599142, -0.0366716 , -0.03081334,  0.03002245,
#          -0.00236005,  0.03726279, -0.01518141,  0.03588073,
#          -0.03512223,  0.04211752],
#         [ 0.03633857, -0.0170511 , -0.020865  , -0.00498838,
#           0.04394497,  0.00207148, -0.04516447, -0.03057182,
#          -0.002909  , -0.02324231],
#         [-0.008884  ,  0.0055187 ,  0.02442347,  0.04745943,
#          -0.03401234,  0.00734911,  0.02716387,  0.04741323,
#           0.0097142 , -0.04605782],
#         [ 0.02277705,  0.0491562 ,  0.01781942, -0.01212945,
#          -0.00443088,  0.00535277, -0.02664676,  0.04224682,
#           0.01397737,  0.04859314],
#         [-0.01573608, -0.04802895, -0.0284688 ,  0.03885159,
#           0.03088601,  0.02471321, -0.02672585, -0.0120634 ,
#          -0.01480012, -0.03953198]],
#
#        [[ 0.04413015,  0.048686  ,  0.006501  , -0.02744819,
#          -0.04518657,  0.02030418, -0.04457892,  0.03195561,
#          -0.04405531,  0.00417024],
#         [ 0.04413015,  0.048686  ,  0.006501  , -0.02744819,
#          -0.04518657,  0.02030418, -0.04457892,  0.03195561,
#          -0.04405531,  0.00417024],
#         [ 0.04413015,  0.048686  ,  0.006501  , -0.02744819,
#          -0.04518657,  0.02030418, -0.04457892,  0.03195561,
#          -0.04405531,  0.00417024],
#         [ 0.01599142, -0.0366716 , -0.03081334,  0.03002245,
#          -0.00236005,  0.03726279, -0.01518141,  0.03588073,
#          -0.03512223,  0.04211752],
#         [ 0.03633857, -0.0170511 , -0.020865  , -0.00498838,
#           0.04394497,  0.00207148, -0.04516447, -0.03057182,
#          -0.002909  , -0.02324231],
#         [-0.008884  ,  0.0055187 ,  0.02442347,  0.04745943,
#          -0.03401234,  0.00734911,  0.02716387,  0.04741323,
#           0.0097142 , -0.04605782],
#         [ 0.02277705,  0.0491562 ,  0.01781942, -0.01212945,
#          -0.00443088,  0.00535277, -0.02664676,  0.04224682,
#           0.01397737,  0.04859314],
#         [ 0.04908902,  0.0106159 ,  0.03736249, -0.01493879,
#           0.02890516, -0.03292227,  0.00969239, -0.03156344,
#           0.04389933,  0.00317071]],
#
#        [[ 0.04413015,  0.048686  ,  0.006501  , -0.02744819,
#          -0.04518657,  0.02030418, -0.04457892,  0.03195561,
#          -0.04405531,  0.00417024],
#         [ 0.04413015,  0.048686  ,  0.006501  , -0.02744819,
#          -0.04518657,  0.02030418, -0.04457892,  0.03195561,
#          -0.04405531,  0.00417024],
#         [ 0.04413015,  0.048686  ,  0.006501  , -0.02744819,
#          -0.04518657,  0.02030418, -0.04457892,  0.03195561,
#          -0.04405531,  0.00417024],
#         [-0.02411859, -0.0349086 ,  0.03013423,  0.00149927,
#           0.04718775, -0.03537065, -0.02561935,  0.00986047,
#          -0.0488658 ,  0.01263073],
#         [ 0.04929603,  0.02197849, -0.01432655, -0.02270597,
#          -0.03673823, -0.02676839,  0.02234468,  0.02094333,
#           0.00256709,  0.03930967],
#         [-0.02927706,  0.03895637,  0.00688553,  0.02848184,
#           0.04035338, -0.02151833, -0.02215278, -0.03933576,
#           0.03684996, -0.04798827],
#         [-0.01425738,  0.01909899, -0.0068404 ,  0.04898309,
#           0.03358111, -0.03556133,  0.01801005,  0.00573983,
#           0.02217904,  0.045626  ],
#         [-0.01812129, -0.03490252, -0.03744742, -0.01211463,
#          -0.04889566, -0.00087111,  0.0439732 ,  0.02205512,
#          -0.0285809 ,  0.04449007]],
#
#        [[ 0.04413015,  0.048686  ,  0.006501  , -0.02744819,
#          -0.04518657,  0.02030418, -0.04457892,  0.03195561,
#          -0.04405531,  0.00417024],
#         [ 0.04413015,  0.048686  ,  0.006501  , -0.02744819,
#          -0.04518657,  0.02030418, -0.04457892,  0.03195561,
#          -0.04405531,  0.00417024],
#         [ 0.04413015,  0.048686  ,  0.006501  , -0.02744819,
#          -0.04518657,  0.02030418, -0.04457892,  0.03195561,
#          -0.04405531,  0.00417024],
#         [ 0.04413015,  0.048686  ,  0.006501  , -0.02744819,
#          -0.04518657,  0.02030418, -0.04457892,  0.03195561,
#          -0.04405531,  0.00417024],
#         [-0.02890893,  0.04871288,  0.01835132,  0.0424833 ,
#           0.01187347,  0.01936025,  0.04459027,  0.04430259,
#           0.01471389,  0.03958443],
#         [-0.02535244,  0.03825498,  0.02007676, -0.04529956,
#           0.0191456 , -0.03388014, -0.03818476, -0.02592476,
#           0.04047186, -0.03350585],
#         [ 0.04843502, -0.03148838, -0.02526485,  0.04351613,
#           0.04018922,  0.024421  , -0.04003011,  0.00619278,
#          -0.01921088,  0.03898473],
#         [ 0.02277705,  0.0491562 ,  0.01781942, -0.01212945,
#          -0.00443088,  0.00535277, -0.02664676,  0.04224682,
#           0.01397737,  0.04859314]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 9758, 1884, 8035, 3719], dtype=int32)

# %%
model.predict(embedded_docs[:1])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# array([[[ 0.04413015,  0.048686  ,  0.006501  , -0.02744819,
#          -0.04518657,  0.02030418, -0.04457892,  0.03195561,
#          -0.04405531,  0.00417024],
#         [ 0.04413015,  0.048686  ,  0.006501  , -0.02744819,
#          -0.04518657,  0.02030418, -0.04457892,  0.03195561,
#          -0.04405531,  0.00417024],
#         [ 0.04413015,  0.048686  ,  0.006501  , -0.02744819,
#          -0.04518657,  0.02030418, -0.04457892,  0.03195561,
#          -0.04405531,  0.00417024],
#         [ 0.04413015,  0.048686  ,  0.006501  , -0.02744819,
#          -0.04518657,  0.02030418, -0.04457892,  0.03195561,
#          -0.04405531,  0.00417024],
#         [ 0.04929603,  0.02197849, -0.01432655, -0.02270597,
#          -0.03673823, -0.02676839,  0.02234468,  0.02094333,
#           0.00256709,  0.03930967],
#         [ 0.01717177, -0.04809495,  0.00635279,  0.03877095,
#          -0.02381608,  0.00574363,  0.04001215,  0.03407898,
#          -0.03609248, -0.0054876 ],
#         [-0.01425738,  0.01909899, -0.0068404 ,  0.04898309,
#           0.03358111, -0.03556133,  0.01801005,  0.00573983,
#           0.02217904,  0.045626  ],
#         [ 0.01075939, -0.02508246,  0.03044936, -0.00063821,
#          -0.01721774,  0.03959969,  0.00388902, -0.02030658,
#           0.03264349, -0.03134723]]], dtype=float32)
